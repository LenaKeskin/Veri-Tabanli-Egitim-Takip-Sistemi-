43,Caleb Sullivan,kpotter@yahoo.com,201,Mathematics,Midterm,67,2025-07-23,present
43,Caleb Sullivan,kpotter@yahoo.com,201,Mathematics,Final,99,2025-07-20,absent
44,Samuel Bryant,anna35@christensen-garcia.com,203,Physics,Midterm,93,2025-07-27,absent
44,Samuel Bryant,anna35@christensen-garcia.com,203,Physics,Final,51,2025-07-23,present
44,Samuel Bryant,anna35@christensen-garcia.com,204,Biology,Midterm,66,2025-07-30,present
44,Samuel Bryant,anna35@christensen-garcia.com,204,Biology,Final,87,2025-06-07,absent
45,Maria Hunter,dennisbrown@hotmail.com,201,Mathematics,Midterm,88,2025-07-25,absent
45,Maria Hunter,dennisbrown@hotmail.com,201,Mathematics,Final,72,2025-06-20,absent
45,Maria Hunter,dennisbrown@hotmail.com,205,History,Midterm,77,2025-07-15,present
45,Maria Hunter,dennisbrown@hotmail.com,205,History,Final,74,2025-06-07,present
46,Joseph Lewis,ghurst@archer.org,203,Physics,Midterm,95,2025-06-16,absent
46,Joseph Lewis,ghurst@archer.org,203,Physics,Final,50,2025-06-15,present
46,Joseph Lewis,ghurst@archer.org,201,Mathematics,Midterm,73,2025-07-19,absent
46,Joseph Lewis,ghurst@archer.org,201,Mathematics,Final,54,2025-07-18,absent
47,Thomas Jones,justinsoto@gallegos.com,205,History,Midterm,92,2025-07-14,present
47,Thomas Jones,justinsoto@gallegos.com,205,History,Final,96,2025-06-13,absent
47,Thomas Jones,justinsoto@gallegos.com,203,Physics,Midterm,82,2025-06-14,absent
47,Thomas Jones,justinsoto@gallegos.com,203,Physics,Final,92,2025-07-20,absent
48,Heather Medina,kelleyjennifer@yahoo.com,203,Physics,Midterm,94,2025-06-22,absent
48,Heather Medina,kelleyjennifer@yahoo.com,203,Physics,Final,85,2025-06-15,present
48,Heather Medina,kelleyjennifer@yahoo.com,204,Biology,Midterm,62,2025-07-03,absent
48,Heather Medina,kelleyjennifer@yahoo.com,204,Biology,Final,92,2025-06-21,absent
49,Victoria Day,bonnie27@hotmail.com,202,English,Midterm,75,2025-06-25,present
49,Victoria Day,bonnie27@hotmail.com,202,English,Final,69,2025-06-08,absent
49,Victoria Day,bonnie27@hotmail.com,203,Physics,Midterm,63,2025-07-02,absent
49,Victoria Day,bonnie27@hotmail.com,203,Physics,Final,100,2025-07-11,absent
50,William Allen,matthew67@gray.com,204,Biology,Midterm,78,2025-07-02,present
50,William Allen,matthew67@gray.com,204,Biology,Final,82,2025-07-27,absent
50,William Allen,matthew67@gray.com,205,History,Midterm,100,2025-06-21,present
50,William Allen,matthew67@gray.com,205,History,Final,92,2025-06-17,present
"""

# Adım 2: Veriyi Pandas DataFrame'e okuma ve JSON'a çevirme
df = pd.read_csv(io.StringIO(csv_data))
records_json_str = df.to_json(orient='records')

# Adım 3: HTML, CSS ve JavaScript şablonunu oluşturma
# Bu şablon, verinin daha sonra ekleneceği özel bir yer tutucu içerir.
html_template = """
<!DOCTYPE html>
<html lang="tr">
<head>
    <meta charset="UTF-8">
    <title>Öğrenci Not Sistemi</title>
    <style>
        body { background-color: #121221; color: #e6e6e6; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; margin: 0; padding: 25px; }
        .container { max-width: 1300px; margin: 0 auto; }
        header { text-align: center; margin-bottom: 30px; }
        header h1 { color: #f0c663; font-size: 2.5em; margin: 0; font-weight: 600; }
        header p { font-size: 1.2em; color: #cddc39; }
        .filters { display: flex; flex-wrap: wrap; justify-content: space-between; align-items: center; margin-bottom: 30px; background-color: #1e1e2f; padding: 15px 20px; border-radius: 8px; gap: 15px; }
        #search-input, .filters select { background-color: #2a2a3e; color: #e6e6e6; border: 1px solid #444; padding: 12px 15px; border-radius: 5px; font-size: 1em; transition: border-color 0.3s, box-shadow 0.3s; }
        #search-input:focus, .filters select:focus { outline: none; border-color: #f0c663; box-shadow: 0 0 5px #f0c66344; }
        #search-input { flex-grow: 1; min-width: 250px; }
        .select-wrapper { display: flex; gap: 15px; flex-wrap: wrap; }
        .card-grid { display: grid; grid-template-columns: repeat(auto-fill, minmax(320px, 1fr)); gap: 25px; }
        .card { background-color: #1e1e2f; border-radius: 8px; overflow: hidden; border: 1px solid #333448; display: flex; transition: transform 0.2s, box-shadow 0.2s; }
        .card:hover { transform: translateY(-6px); box-shadow: 0 10px 20px #00000055; border-color: #f0c663; }
        .score-display { flex-shrink: 0; width: 100px; display: flex; flex-direction: column; align-items: center; justify-content: center; padding: 10px; text-align: center; }
        .score-value { font-size: 36px; font-weight: bold; color: #fff; line-height: 1; }
        .score-label { font-size: 14px; color: #e0e0e0; margin-top: 5px; }
        .card-content { padding: 15px; display: flex; flex-direction: column; flex-grow: 1; min-width: 0; }
        .card-content h3 { margin: 0 0 5px 0; color: #fff; font-size: 1.2em; white-space: nowrap; overflow: hidden; text-overflow: ellipsis; }
        .card-info { margin-top: 10px; font-size: 0.9em; }
        .info-item { color: #ccc; margin-bottom: 6px; white-space: nowrap; overflow: hidden; text-overflow: ellipsis; }
        .info-item span { color: #fff; font-weight: 500; }
        .attendance-tag { padding: 3px 8px; border-radius: 12px; font-size: 0.8em; color: #fff; }
        .present { background-color: #2e7d32; }
        .absent { background-color: #c62828; }
    </style>
</head>
<body>
    <div class="container">
        <header>
            <h1>Öğrenci Not Sistemi</h1>
            <p>Veri Bankası</p>
        </header>
        <nav class="filters">
            <div class="search-wrapper">
                <input type="text" id="search-input" placeholder="Öğrenci adı ile ara...">
            </div>
            <div class="select-wrapper">
                <select id="course-filter"><option value="all">Tüm Dersler</option></select>
                <select id="exam-type-filter"><option value="all">Tüm Sınav Türleri</option></select>
            </div>
        </nav>
        <main id="card-container" class="card-grid"></main>
    </div>

    <script>
        // Bu fonksiyonun içindeki tüm kod, sayfa yüklendiğinde çalışır.
        function startApp() {
            // Python'dan gelen veriyi bu özel yer tutucudan alıyoruz.
            const examData = __JSON_DATA_PLACEHOLDER__;

            const cardContainer = document.getElementById('card-container');
            const searchInput = document.getElementById('search-input');
            const courseFilter = document.getElementById('course-filter');
            const examTypeFilter = document.getElementById('exam-type-filter');

            function displayCards(data) {
                cardContainer.innerHTML = '';
                if (data.length === 0) {
                    cardContainer.innerHTML = '<p style="color: #aaa; grid-column: 1 / -1; text-align: center;">Filtrelere uygun sonuç bulunamadı.</p>';
                    return;
                }
                data.forEach(record => {
                    const card = document.createElement('div');
                    card.className = 'card';
                    const attendanceClass = record.Attendance_Status === 'present' ? 'present' : 'absent';
                    const attendanceText = record.Attendance_Status === 'present' ? 'Katıldı' : 'Katılmadı';
                    const scoreColor = record.Score >= 90 ? '#4CAF50' : record.Score >= 70 ? '#3498db' : record.Score >= 50 ? '#f1c40f' : '#c62828';

                    card.innerHTML = `
                        <div class="score-display" style="background-color: ${scoreColor};">
                            <div class="score-value">${record.Score}</div>
                            <div class="score-label">PUAN</div>
                        </div>
                        <div class="card-content">
                            <h3>${record.Student_Name}</h3>
                            <div class="card-info">
                                <div class="info-item">Ders: <span>${record.Course_Name}</span></div>
                                <div class="info-item">Sınav: <span>${record.Exam_Type}</span></div>
                                <div class="info-item">Devam: <span class="attendance-tag ${attendanceClass}">${attendanceText}</span></div>
                            </div>
                        </div>
                    `;
                    cardContainer.appendChild(card);
                });
            }

            function populateFilters() {
                const allCourses = [...new Set(examData.map(item => item.Course_Name))].sort();
                const allExamTypes = [...new Set(examData.map(item => item.Exam_Type))].sort();

                allCourses.forEach(course => {
                    courseFilter.innerHTML += `<option value="${course}">${course}</option>`;
                });
                allExamTypes.forEach(type => {
                    examTypeFilter.innerHTML += `<option value="${type}">${type}</option>`;
                });
            }

            function filterAndDisplay() {
                const searchTerm = searchInput.value.toLowerCase();
                const selectedCourse = courseFilter.value;
                const selectedExamType = examTypeFilter.value;

                const filteredData = examData.filter(record => {
                    const nameMatch = record.Student_Name.toLowerCase().includes(searchTerm);
                    const courseMatch = selectedCourse === 'all' || record.Course_Name === selectedCourse;
                    const examTypeMatch = selectedExamType === 'all' || record.Exam_Type === selectedExamType;
                    return nameMatch && courseMatch && examTypeMatch;
                });
                displayCards(filteredData);
            }

            // Olay dinleyicilerini ekle
            searchInput.addEventListener('input', filterAndDisplay);
            courseFilter.addEventListener('change', filterAndDisplay);
            examTypeFilter.addEventListener('change', filterAndDisplay);

            // Başlangıç fonksiyonlarını çağır
            populateFilters();
            filterAndDisplay();
        }

        // Uygulamayı başlat
        startApp();
    </script>
</body>
</html>
"""

# Adım 4: Güvenli Yöntem: Veriyi .replace() ile şablonun içine yerleştirme
# Bu yöntem, süslü parantez (KeyError) hatasını tamamen önler.
final_html = html_template.replace('__JSON_DATA_PLACEHOLDER__', records_json_str)

# Adım 5: Sonuçları Colab'da gösterme
HTML(final_html)
# Out:
# <!DOCTYPE html>
# <html lang="tr">
# <head>
#     <meta charset="UTF-8">
#     <title>Öğrenci Not Sistemi</title>
#     <style>
#         body { background-color: #121221; color: #e6e6e6; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; margin: 0; padding: 25px; }
#         .container { max-width: 1300px; margin: 0 auto; }
#         header { text-align: center; margin-bottom: 30px; }
#         header h1 { color: #f0c663; font-size: 2.5em; margin: 0; font-weight: 600; }
#         header p { font-size: 1.2em; color: #cddc39; }
#         .filters { display: flex; flex-wrap: wrap; justify-content: space-between; align-items: center; margin-bottom: 30px; background-color: #1e1e2f; padding: 15px 20px; border-radius: 8px; gap: 15px; }
#         #search-input, .filters select { background-color: #2a2a3e; color: #e6e6e6; border: 1px solid #444; padding: 12px 15px; border-radius: 5px; font-size: 1em; transition: border-color 0.3s, box-shadow 0.3s; }
# ...
